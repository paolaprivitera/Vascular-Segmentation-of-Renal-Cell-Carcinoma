# %% [markdown]
# # Import

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# # Autoencoder
# Epochs = 1000, batch = 8, preprocess = norm
#
# Variazione di LR

# %%
LR_df = pd.DataFrame({
   "Mean IoU": [0.4629044, 0.47821796, 0.53378814, 0.08759778, 0.08759778],
   "IoU minority": [0.20897587435974968, 0.2431395666, 0.2709558996564221, 0.15863411554246026, 0.15863411554246026],
   "Dice minority": [0.34570726975080335, 0.3911701842, 0.4263812768478744, 0.27382952636120067, 0.27382952636120067]
   }, index = ["0.00001", "0.0001", "0.001", "0.01", "0.1"])


f = plt.figure(figsize=(12,5))
plt.plot(LR_df,linewidth=2,marker ='o',markersize=8)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.yticks(np.arange(0, 0.8, 0.1))
plt.xlabel("Learning Rates",size=15,labelpad=10)
#plt.ylabel("Mean IoU",size=15)
plt.ylabel("Evaluation Metrics",size=15)
plt.ylim(0, 0.8)
plt.legend(LR_df,prop={'size': 15})
plt.show()

# %% [markdown]
# LR = 0.001, batch = 8, preprocess = norm
#
# Variazione delle epoche

# %%
Epochs_df = pd.DataFrame({
   "Mean IoU": [0.09756237, 0.087620385, 0.51974165, 0.52230906, 0.53378814],
   "IoU minority": [0.15940916214056, 0.15863951642107021, 0.2667228180907094, 0.251130043781801, 0.2709558996564221],
   "Dice minority": [0.2749834438883521, 0.2738375727268356, 0.421122623326123, 0.40144514957487254, 0.4263812768478744]
   }, index = ["50", "200", "400", "800", "1000"])


f = plt.figure(figsize=(12,5))
plt.plot(Epochs_df,linewidth=2,marker ='o',markersize=8)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.yticks(np.arange(0, 0.8, 0.1))
plt.xlabel("Epochs",size=15,labelpad=10)
plt.ylabel("Evaluation Metrics",size=15)
plt.ylim(0, 0.8)
plt.legend(Epochs_df,prop={'size': 15})
plt.show()

# %% [markdown]
# LR = 0.001, epochs = 1000, batch = 8
#
# Variazione del preprocessing

# %%
preproc_df = pd.DataFrame({
   "Mean IoU": [0.49326038, 0.51772654, 0.5177599, 0.53378814],
   "IoU minority": [0.19361075767781852, 0.23896018746736927, 0.24950989945773672, 0.2709558996564221],
   "Dice minority": [0.32441188458202264, 0.3857431253797456, 0.39937242524612127, 0.4263812768478744]
   }, index = ["Base", "Histogram Equalization", "CLAHE", "H&E Normalization"])


f = plt.figure(figsize=(12,5))
plt.plot(preproc_df,linewidth=2,marker ='o',markersize=8)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.yticks(np.arange(0, 0.8, 0.1))
plt.xlabel("Preprocessing Techniques",size=15,labelpad=10)
plt.ylabel("Evaluation Metrics",size=15)
plt.ylim(0, 0.8)
plt.legend(preproc_df,prop={'size': 15})
plt.show()

# %% [markdown]
# Epochs = 1000, batch = 8, preprocess = norm
#
# Variazione del dataset
#
# Nota (LR = 0.001 per tumori singoli e LR = 0.00001 per tumori insieme)

# %%
headerColor = 'SkyBlue'
rowEvenColor = 'Azure'
rowOddColor = 'FloralWhite'

fig = go.Figure(data=[go.Table(
  #columnwidth = [40,40,40,40,40,40,40],
  header=dict(
    values=['<b>Dataset</b>','<b>Mean IoU</b>','<b>IoU Minority</b>','<b>Dice Minority</b>'],
    line_color='darkslategray',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=13),
    height = 30
    
  ),
  cells=dict(
    values=[["pRCC", "ccRCC", "pRCC+ccRCC"],
   [0.53378814, 0.5476335, 0.3365001],
   [0.2709558996564221, 0.37982286231997253, 0.2234816844656442],
   [0.4263812768478744, 0.5505385838894643, 0.36532085000234366]],
    line_color='darkslategray',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor,rowOddColor, rowEvenColor,rowOddColor]],
    align = ['left', 'center'],
    font = dict(color = 'darkslategray', size = 12)
    ))
])

fig.update_layout(width=900, height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #PATCH

# %%
datasets_df = pd.DataFrame({
   "Dataset": ['Original PrCC','Patches PrCC'],
   "Epochs": [1000, 1000],
   "Batch size": [8,64],
   "Learining Rate":[0.001,0.0001],
   "Mean IoU":[0.53379,0.42382],
   "IoU minority":[0.27096,0.15898],
   "Dice minority":[0.42638,0.27434]
   })

KNN_results_df_new = pd.DataFrame(datasets_df)
KNN_results_df_new
# Out:
#          Dataset  Epochs  Batch size  Learining Rate  Mean IoU  IoU minority  \
# 0  Original PrCC    1000           8          0.0010   0.53379       0.27096
# 1   Patches PrCC    1000          64          0.0001   0.42382       0.15898
#
#    Dice minority
# 0        0.42638
# 1        0.27434

# %%
headerColor = 'grey'
rowEvenColor = 'LightCyan'
rowOddColor = 'LightBlue'

fig = go.Figure(data=[go.Table(
  #columnwidth = [40,40,40,40,40,40,40],
  header=dict(
    values=['<b>Dataset</b>','<b>Epochs</b>','<b>Batch size</b>','<b>Learining Rate</b>','<b>Mean IoU</b>','<b>IoU minority</b>','<b>Dice minority</b>'],
    line_color='darkslategray',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=13),
    height = 30
    
  ),
  cells=dict(
    values=[['Original PrCC','Patches PrCC'],
   [1000, 1000],
   [8,64],
   [0.001,0.0001],
   [0.53379,0.42382],
   [0.27096,0.15898],
   [0.42638,0.27434]],
    line_color='darkslategray',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor,rowOddColor, rowEvenColor,rowOddColor]],
    align = ['left', 'center'],
    font = dict(color = 'darkslategray', size = 12)
    ))
])

fig.update_layout(width=900, height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # UNET
# Epochs = 370, batch = 16, preprocess = norm
#
# Variazione di LR

# %%
LR_df = pd.DataFrame({
   "Mean IoU": [0.5025377, 0.50550705, 0.5654956, 0.5664475, 0.5730026],
   "IoU minority": [0.19045632188703912, 0.17111705947639877, 0.2837370242214533, 0.29092791321591044, 0.3171680532008569],
   "Dice minority": [0.31997196097902914, 0.2922287880477199, 0.4420485175202156, 0.4507268147780024, 0.4815908682724352]
   }, index = ["0.00001", "0.0001", "0.001", "0.01", "0.1"])


f = plt.figure(figsize=(12,5))
plt.plot(LR_df,linewidth=2,marker ='o',markersize=8)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.yticks(np.arange(0, 0.8, 0.1))
plt.xlabel("Learning Rates",size=15,labelpad=10)
#plt.ylabel("Mean IoU",size=15)
plt.ylabel("Evaluation Metrics",size=15)
plt.ylim(0, 0.8)
plt.legend(LR_df,prop={'size': 15})
plt.show()

# %% [markdown]
# LR = 0.1, batch = 16, preprocess = norm
#
# Variazione delle epoche

# %%
Epochs_df = pd.DataFrame({
   "Mean IoU": [0.4213937, 0.4299954, 0.42172053, 0.5730026, 0.56715834],
   "IoU minority": [0.0007529684332464524, 0.016428763802854834, 0.0018086314047678603, 0.3171680532008569, 0.2969490187232123],
   "Dice minority": [0.0015048037967357332, 0.03232644409114997, 0.003610732325657326, 0.4815908682724352, 0.45791933905859333]
   }, index = ["50", "100", "200", "370", "500"])


f = plt.figure(figsize=(12,5))
plt.plot(Epochs_df,linewidth=2,marker ='o',markersize=8)
plt.grid()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.yticks(np.arange(0, 0.8, 0.1))
plt.xlabel("Epochs",size=15,labelpad=10)
plt.ylabel("Evaluation Metrics",size=15)
plt.ylim(0, 0.8)
plt.legend(Epochs_df,prop={'size': 15})
plt.show()

# %% [markdown]
# LR = 0.1, epochs = 370, batch = 16, preprocess = norm
#
# Variazione del dataset

# %%
headerColor = 'SkyBlue'
rowEvenColor = 'Azure'
rowOddColor = 'FloralWhite'

fig = go.Figure(data=[go.Table(
  #columnwidth = [40,40,40,40,40,40,40],
  header=dict(
    values=['<b>Dataset</b>','<b>Mean IoU</b>','<b>IoU Minority</b>','<b>Dice Minority</b>'],
    line_color='darkslategray',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=13),
    height = 30
    
  ),
  cells=dict(
    values=[["pRCC", "ccRCC", "pRCC+ccRCC"],
   [0.5730026, 0.5610693, 0.55349886],
   [0.3171680532008569, 0.3882488006888351, 0.28494036],
   [0.4815908682724352, 0.5593360505641207, 0.4435075454438602]],
    line_color='darkslategray',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor,rowOddColor, rowEvenColor,rowOddColor]],
    align = ['left', 'center'],
    font = dict(color = 'darkslategray', size = 12)
    ))
])

fig.update_layout(width=900, height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Pix2Pix
#
# LR 0.00001

# %%
Epochs_df = pd.DataFrame({
   "Batch 8": [0.3056449598740852, 0.2967433984848264, 0.16373198552011475, 0.12184615384615384, 0.10924197837820826, 0.11609490518761408],
   "Batch 16": [0.2803116624673011,0.3532311499620804,0.3288734036214802,0.20748113972947774,0.17287974468663,0.1622567489380918],
   "Batch 64": [0.2603391653383011,0.27763826715677353,0.3066867413360973,0.3568176062764885,0.3684888528745663,0.36972571757313916]
   }, index = ["10", "50", "100", "200", "300", "400"])


f = plt.figure(figsize=(12,5))
plt.plot(Epochs_df,linewidth=2,marker ='o',markersize=8)
plt.grid()
plt.yticks(np.arange(0, 0.8, 0.1))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("Epochs",size=15,labelpad=10)
plt.ylabel("Dice",size=15)
plt.ylim(0, 0.8)
plt.legend(Epochs_df,prop={'size': 15})
plt.show()

# %% [markdown]
# Variazione del dataset

# %%
headerColor = 'SkyBlue'
rowEvenColor = 'Azure'
rowOddColor = 'FloralWhite'

fig = go.Figure(data=[go.Table(
  #columnwidth = [40,40,40,40,40,40,40],
  header=dict(
    values=['<b>Dataset</b>','<b>Mean IoU</b>','<b>IoU Minority</b>','<b>Dice Minority</b>','<b>Epochs</b>'],
    line_color='darkslategray',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=13),
    height = 30
    
  ),
  cells=dict(
    values=[["pRCC", "ccRCC", "pRCC+ccRCC"],
   [0.42393038,0.37890804, 0.43870416],
   [0.226787, 0.297376, 0.2272085],
   [0.3697257, 0.458426, 0.370285],
   [400,400,300]],
    line_color='darkslategray',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor,rowOddColor, rowEvenColor,rowOddColor]],
    align = ['left', 'center'],
    font = dict(color = 'darkslategray', size = 12)
    ))
])

fig.update_layout(width=900, height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Conclusion

# %%
colours = {
    "Mean_IoU": "#318f9a",
    "Minority_IoU": "#73c868",
    "Minority_Dice": "#e46d6d",
}

df = pd.DataFrame([['Mean_IoU','Autoencoder',0.53379],['Mean_IoU','UNET',0.57300],['Mean_IoU','Pix2Pix',0.42393],['Minority_IoU','Autoencoder',0.27096],
                   ['Minority_IoU','UNET',0.31717],['Minority_IoU','Pix2Pix',0.22679],['Minority_Dice','Autoencoder',0.42638],
                   ['Minority_Dice','UNET',0.48159],['Minority_Dice','Pix2Pix',0.36972]],columns=['Metrics','Model','value'])

import plotly.express as px

fig = px.bar(df, x="Model", y="value",
             color='Metrics', barmode='group',text="value",
             height=400,color_discrete_map=colours)
fig.update_layout(width=900, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
